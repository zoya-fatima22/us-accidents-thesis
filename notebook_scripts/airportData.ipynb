# %%
import pandas as pd

# %%
df = pd.read_csv('../data/iata-icao.csv')
df
# Out:
#      country_code         region_name iata  icao  \
# 0              AE            Abu Zaby  AAN  OMAL
# 1              AE            Abu Zaby  AUH  OMAA
# 2              AE            Abu Zaby  AYM   NaN
# 3              AE            Abu Zaby  AZI  OMAD
# 4              AE            Abu Zaby  DHF  OMAM
# ...           ...                 ...  ...   ...
# 9153           ZW            Masvingo  MVZ  FVMV
# 9154           ZW  Matabeleland North  HWN  FVWN
# 9155           ZW  Matabeleland North  VFA  FVFA
# 9156           ZW  Matabeleland North  WKI  FVWT
# 9157           ZW            Midlands  GWE  FVTL
#
#                               airport  latitude  longitude
# 0        Al Ain International Airport   24.2617    55.6092
# 1     Abu Dhabi International Airport   24.4330    54.6511
# 2            Yas Island Seaplane Base   24.4670    54.6103
# 3         Al Bateen Executive Airport   24.4283    54.4581
# 4                  Al Dhafra Air Base   24.2482    54.5477
# ...

# %%
df_us = df[df['country_code'] == 'US']
df_us
# Out:
#      country_code region_name iata  icao  \
# 6803           US     Alabama  AIV  KAIV
# 6804           US     Alabama  ALX  KALX
# 6805           US     Alabama  ANB  KANB
# 6806           US     Alabama  ASN  KASN
# 6807           US     Alabama  AUO  KAUO
# ...           ...         ...  ...   ...
# 8832           US     Wyoming  SAA  KSAA
# 8833           US     Wyoming  SHR  KSHR
# 8834           US     Wyoming  THP  KTHP
# 8835           US     Wyoming  TOR  KTOR
# 8836           US     Wyoming  WRL  KWRL
#
#                                                airport  latitude  longitude
# 6803                             George Downer Airport   33.1065   -88.1978
# 6804                           Thomas C. Russell Field   32.9147   -85.9630
# 6805                         Anniston Regional Airport   33.5882   -85.8581
# 6806                       Talladega Municipal Airport   33.5699   -86.0509
# 6807                Auburn University Regional Airport   32.6151   -85.4340
# ...

# %%
df_us.to_parquet('../data/iata-icao-us.parquet')
