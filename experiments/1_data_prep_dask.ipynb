# %%
import dask.dataframe as dd
import numpy as np
import pyarrow
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import dask
print("Dask version:", dask.__version__)
# Out:
# Dask version: 2025.7.0

# %%
ddf = dd.read_parquet('../data/us_accidents.parquet')
ddf.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 46 columns]

# %%
ddf.info()
# Out:
# <class 'dask.dataframe.dask_expr.DataFrame'>
# Columns: 46 entries, ID to Astronomical_Twilight
# dtypes: bool(13), float64(12), int64(1), string(20)

# %%
ddf.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
ddf = ddf.drop(columns=['ID', 'Source', 'Distance(mi)', 'End_Time', 'Duration', 'End_Lat', 'End_Lng', 'Description','Country', 'Street', 'Weather_Timestamp', 'Timezone', 'Zipcode'], errors='ignore')

# %%
print(ddf.dtypes)
print(ddf.shape)
# Out:
# Severity                           int64
# Start_Time               string[pyarrow]
# Start_Lat                        float64
# Start_Lng                        float64
# City                     string[pyarrow]
# County                   string[pyarrow]
# State                    string[pyarrow]
# Airport_Code             string[pyarrow]
# Temperature(F)                   float64
# Wind_Chill(F)                    float64
# Humidity(%)                      float64
# Pressure(in)                     float64
# Visibility(mi)                   float64
# Wind_Direction           string[pyarrow]
# Wind_Speed(mph)                  float64
# Precipitation(in)                float64
# Weather_Condition        string[pyarrow]
# Amenity                             bool
# Bump                                bool
# Crossing                            bool
# Give_Way                            bool
# Junction                            bool
# No_Exit                             bool
# Railway                             bool
# Roundabout                          bool
# Station                             bool
# Stop                                bool
# Traffic_Calming                     bool
# Traffic_Signal                      bool
# Turning_Loop                        bool
# Sunrise_Sunset           string[pyarrow]
# Civil_Twilight           string[pyarrow]
# Nautical_Twilight        string[pyarrow]
# Astronomical_Twilight    string[pyarrow]
# dtype: object
# (<dask_expr.expr.Scalar: expr=(Drop(frame=ReadParquetFSSpec(1cea313), columns=['ID', 'Source', 'Distance(mi)', 'End_Time', 'Duration', 'End_Lat', 'End_Lng', 'Description', 'Country', 'Street', 'Weather_Timestamp', 'Timezone', 'Zipcode'], errors='ignore')).size() // 34, dtype=int64>, 34)

# %%
ddf['Start_Time'] = dd.to_datetime(ddf['Start_Time'], format='mixed')

# %%
ddf.columns
# Out:
# Index(['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'County',
#        'State', 'Airport_Code', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
ddf_airports = dd.read_csv('../data/data-world-us-airports.csv',
                           dtype={'continent': 'object', 
                                   'elevation_ft': 'float64', 
                                   'iata_code': 'object', 
                                   'icao_code': 'object'}
                                   )

# %%
ddf_airports = ddf_airports.drop(columns=['type', 'elevation_ft', 'continent', 'iso_country', 'iso_region', 'municipality', 'icao_code', 'iata_code'], errors='ignore').compute()

# %%
ddf_airports.head()
# Out:
#   ident                  name gps_code local_code  \
# 0   00A     Total RF Heliport     K00A        00A
# 1  00AA  Aero B Ranch Airport     00AA       00AA
# 2  00AK          Lowell Field     00AK       00AK
# 3  00AL          Epps Airpark     00AL       00AL
# 4  00AN  Katmai Lodge Airport     00AN       00AN
#
#                              coordinates
# 0                  40.070985, -74.933689
# 1                 38.704022, -101.473911
# 2                 59.947733, -151.692524
# 3  34.86479949951172, -86.77030181884766
# 4                 59.093287, -156.456699

# %%
# Split coordinates
ddf_airports[['latitude', 'longitude']] = ddf_airports['coordinates'].str.split(',', expand=True)
ddf_airports['latitude'] = ddf_airports['latitude'].astype(float)
ddf_airports['longitude'] = ddf_airports['longitude'].astype(float)
ddf_airports = ddf_airports.drop(columns=['coordinates'], errors='ignore')

# %%
ddf_airports = ddf_airports.rename(columns={'ident': 'Airport_Code', 'name': 'airport_name'})

# %%
ddf_airports.head()
# Out:
#   Airport_Code          airport_name gps_code local_code   latitude  \
# 0          00A     Total RF Heliport     K00A        00A  40.070985
# 1         00AA  Aero B Ranch Airport     00AA       00AA  38.704022
# 2         00AK          Lowell Field     00AK       00AK  59.947733
# 3         00AL          Epps Airpark     00AL       00AL  34.864799
# 4         00AN  Katmai Lodge Airport     00AN       00AN  59.093287
#
#     longitude
# 0  -74.933689
# 1 -101.473911
# 2 -151.692524
# 3  -86.770302
# 4 -156.456699

# %%
ddf = ddf.merge(ddf_airports, how='left', left_on='Airport_Code', right_on='Airport_Code', suffixes=('', '_airport'))

# %%
ddf.head()
# Out:
#    Severity          Start_Time  Start_Lat  Start_Lng          City  \
# 0         3 2016-02-08 05:46:00  39.865147 -84.058723        Dayton
# 1         2 2016-02-08 06:07:59  39.928059 -82.831184  Reynoldsburg
# 2         2 2016-02-08 06:49:27  39.063148 -84.032608  Williamsburg
# 3         3 2016-02-08 07:23:34  39.747753 -84.205582        Dayton
# 4         2 2016-02-08 07:39:07  39.627781 -84.188354        Dayton
#
#        County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 0  Montgomery    OH         KFFO            36.9            NaN  ...
# 1    Franklin    OH         KCMH            37.9            NaN  ...
# 2    Clermont    OH         KI69            36.0           33.3  ...
# 3  Montgomery    OH         KDAY            35.1           31.0  ...
# 4  Montgomery    OH         KMGY            36.0           33.3  ...
#
#    Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0         False           Night           Night             Night
# 1         False           Night           Night             Night
# 2         False           Night           Night               Day
# 3         False           Night             Day               Day
# 4         False             Day             Day               Day
#
#    Astronomical_Twilight                              airport_name gps_code  \
# 0                  Night           Wright-Patterson Air Force Base     KFFO
# 1                    Day                                      <NA>     <NA>
# 2                    Day                   Clermont County Airport     KI69
# 3                    Day  James M Cox Dayton International Airport     KDAY
# 4                    Day            Dayton-Wright Brothers Airport     KMGY
#
#    local_code   latitude  longitude
# 0         FFO  39.826099 -84.048302
# 1        <NA>        NaN        NaN
# 2         I69  39.078400 -84.210197
# 3         DAY  39.902401 -84.219398
# 4         MGY  39.589001 -84.224899
#
# [5 rows x 39 columns]

# %%
ddf[ddf['airport_name'].isna() & (~ddf['Airport_Code'].isna())].compute()
# Out:
#          Severity          Start_Time  Start_Lat   Start_Lng            City  \
# 1               2 2016-02-08 06:07:59  39.928059  -82.831184    Reynoldsburg
# 6096            2 2016-12-07 21:30:53  38.642143 -121.162064  Rancho Cordova
# 6722            2 2016-12-10 20:10:47  37.563786 -122.306152       San Mateo
# 8415            2 2016-12-23 17:08:55  37.848099 -122.488701       Sausalito
# 15746           2 2016-11-08 11:54:51  38.590389 -121.785675           Davis
# ...           ...                 ...        ...         ...             ...
# 1709292         4 2019-08-23 17:01:58  40.374860 -120.399344      Susanville
# 1709293         4 2019-08-23 17:01:58  40.370829 -120.400948      Susanville
# 1709297         3 2019-08-23 04:04:48  34.075790 -118.276680     Los Angeles
# 1709301         2 2019-08-23 12:52:31  34.023790 -118.276390     Los Angeles
# 1709304         2 2019-08-23 13:42:50  34.070610 -118.263910     Los Angeles
#
#               County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 1           Franklin    OH         KCMH            37.9            NaN  ...
# 6096      Sacramento    CA         KMHR            42.8           40.1  ...
# 6722       San Mateo    CA         KSQL            57.2            NaN  ...
# 8415           Marin    CA         KSFO            50.0            NaN  ...
# 15746           Yolo    CA         KEDU            69.8            NaN  ...
# ...              ...   ...          ...             ...            ...  ...
# 1709292       Lassen    CA         KRTS            90.0           90.0  ...
# 1709293       Lassen    CA         KRTS            90.0           90.0  ...
# 1709297  Los Angeles    CA         KCQT            67.0           67.0  ...
# 1709301  Los Angeles    CA         KCQT            81.0           81.0  ...
# 1709304  Los Angeles    CA         KCQT            82.0           82.0  ...
#
#          Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 1               False           Night           Night             Night
# 6096            False           Night           Night             Night
# 6722            False           Night           Night             Night
# 8415            False           Night             Day               Day
# 15746           False             Day             Day               Day
# ...               ...             ...             ...               ...
# 1709292         False             Day             Day               Day
# 1709293         False             Day             Day               Day
# 1709297         False           Night           Night             Night
# 1709301         False             Day             Day               Day
# 1709304         False             Day             Day               Day
#
#          Astronomical_Twilight  airport_name gps_code  local_code  latitude  \
# 1                          Day          <NA>     <NA>        <NA>       NaN
# 6096                     Night          <NA>     <NA>        <NA>       NaN
# 6722                     Night          <NA>     <NA>        <NA>       NaN
# 8415                       Day          <NA>     <NA>        <NA>       NaN
# 15746                      Day          <NA>     <NA>        <NA>       NaN
# ...                        ...           ...      ...         ...       ...
# 1709292                    Day          <NA>     <NA>        <NA>       NaN
# 1709293                    Day          <NA>     <NA>        <NA>       NaN
# 1709297                  Night          <NA>     <NA>        <NA>       NaN
# 1709301                    Day          <NA>     <NA>        <NA>       NaN
# 1709304                    Day          <NA>     <NA>        <NA>       NaN
#
#          longitude
# 1              NaN
# 6096           NaN
# 6722           NaN
# 8415           NaN
# 15746          NaN
# ...            ...
# 1709292        NaN
# 1709293        NaN
# 1709297        NaN
# 1709301        NaN
# 1709304        NaN
#
# [583666 rows x 39 columns]

# %%
print(type(ddf['Airport_Code']))
# Out:
# <class 'dask.dataframe.dask_expr._collection.Series'>

# %%
# Manual corrections
airport_corrections = {
    'KCQT': {
        'airport_name': 'Whiteman Airport',
        'latitude': 34.2598,
        'longitude': -118.4119
    },
    'KMCJ': {
        'airport_name': 'William P Hobby Airport',
        'latitude': 29.6459,
        'longitude': -95.2769
    },
    'KATT': {
        'airport_name': 'Austin–Bergstrom International Airport',
        'latitude': 30.197535,
        'longitude': -97.662015
    },
    'KJRB': {
        'airport_name': 'Downtown Manhattan Heliport',
        'latitude': 40.700711,
        'longitude': -74.008573
    },
    'KDMH': {
        'airport_name': 'Baltimore/Washington International Airport',
        'latitude': 39.1718,
        'longitude': -76.6677
    }
}

# %%
def apply_corrections(df):
    for code, info in airport_corrections.items():
        mask = df['Airport_Code'] == code
        for col, value in info.items():
            df.loc[mask, col] = value
    return df

# %%
ddf = ddf.map_partitions(apply_corrections)

# %%
print(ddf[ddf['airport_name'].isna()]['Airport_Code'].value_counts(sort=True).compute())
# Out:
# Airport_Code
# KNYC    24649
# K3A6    19046
# KAUD    17034
# KMWS    12349
# KNKA    11155
#         ...
# KWVL        1
# KWYS        1
# KY19        1
# KY22        1
# KY50        1
# Name: count, Length: 1354, dtype: int64[pyarrow]

# %%
conditional_airport_data = {
    'KNYC': {
        'Kings': {
            'airport_name': 'John F. Kennedy International Airport (JFK)',
            'latitude': 40.64013,
            'longitude': -73.77651
        },
        'New York': {
            'airport_name': 'LaGuardia Airport (LGA)',
            'latitude': 40.7769,
            'longitude': -73.8740
        },
        'Hudson': {
            'airport_name': 'Newark Liberty International Airport (EWR)',
            'latitude': 40.6925,
            'longitude': -74.1687
        },
        'Queens': {
            'airport_name': 'John F. Kennedy International Airport (JFK)',
            'latitude': 40.64013,
            'longitude': -73.77651
        },
        'Bergen': {
            'airport_name': 'Teterboro Airport (TEB)',
            'latitude': 40.8502,
            'longitude': -74.0609
        }
    }
}

# %%
def apply_conditional_corrections(df):
    for code, county_map in conditional_airport_data.items():
        for county, info in county_map.items():
            mask = (df['Airport_Code'] == code) & (df['County'] == county)
            for col, value in info.items():
                df.loc[mask, col] = value
    return df

# %%
ddf = ddf.map_partitions(apply_conditional_corrections)

# %%
ddf[ddf['airport_name'].isna() & (~ddf['Airport_Code'].isna())].compute()
# Out:
#          Severity          Start_Time  Start_Lat   Start_Lng            City  \
# 1               2 2016-02-08 06:07:59  39.928059  -82.831184    Reynoldsburg
# 6096            2 2016-12-07 21:30:53  38.642143 -121.162064  Rancho Cordova
# 6722            2 2016-12-10 20:10:47  37.563786 -122.306152       San Mateo
# 8415            2 2016-12-23 17:08:55  37.848099 -122.488701       Sausalito
# 15746           2 2016-11-08 11:54:51  38.590389 -121.785675           Davis
# ...           ...                 ...        ...         ...             ...
# 1709151         2 2019-08-23 01:59:56  42.430325 -123.252602     Grants Pass
# 1709202         2 2019-08-23 12:20:38  42.437790 -123.285592     Grants Pass
# 1709213         2 2019-08-23 12:52:07  45.460548 -123.803174       Tillamook
# 1709292         4 2019-08-23 17:01:58  40.374860 -120.399344      Susanville
# 1709293         4 2019-08-23 17:01:58  40.370829 -120.400948      Susanville
#
#              County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 1          Franklin    OH         KCMH            37.9            NaN  ...
# 6096     Sacramento    CA         KMHR            42.8           40.1  ...
# 6722      San Mateo    CA         KSQL            57.2            NaN  ...
# 8415          Marin    CA         KSFO            50.0            NaN  ...
# 15746          Yolo    CA         KEDU            69.8            NaN  ...
# ...             ...   ...          ...             ...            ...  ...
# 1709151   Josephine    OR         KSXT            58.0           58.0  ...
# 1709202   Josephine    OR         KSXT            70.0           70.0  ...
# 1709213   Tillamook    OR         KS47            70.0           70.0  ...
# 1709292      Lassen    CA         KRTS            90.0           90.0  ...
# 1709293      Lassen    CA         KRTS            90.0           90.0  ...
#
#          Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 1               False           Night           Night             Night
# 6096            False           Night           Night             Night
# 6722            False           Night           Night             Night
# 8415            False           Night             Day               Day
# 15746           False             Day             Day               Day
# ...               ...             ...             ...               ...
# 1709151         False           Night           Night             Night
# 1709202         False             Day             Day               Day
# 1709213         False             Day             Day               Day
# 1709292         False             Day             Day               Day
# 1709293         False             Day             Day               Day
#
#          Astronomical_Twilight  airport_name gps_code  local_code  latitude  \
# 1                          Day          <NA>     <NA>        <NA>       NaN
# 6096                     Night          <NA>     <NA>        <NA>       NaN
# 6722                     Night          <NA>     <NA>        <NA>       NaN
# 8415                       Day          <NA>     <NA>        <NA>       NaN
# 15746                      Day          <NA>     <NA>        <NA>       NaN
# ...                        ...           ...      ...         ...       ...
# 1709151                  Night          <NA>     <NA>        <NA>       NaN
# 1709202                    Day          <NA>     <NA>        <NA>       NaN
# 1709213                    Day          <NA>     <NA>        <NA>       NaN
# 1709292                    Day          <NA>     <NA>        <NA>       NaN
# 1709293                    Day          <NA>     <NA>        <NA>       NaN
#
#          longitude
# 1              NaN
# 6096           NaN
# 6722           NaN
# 8415           NaN
# 15746          NaN
# ...            ...
# 1709151        NaN
# 1709202        NaN
# 1709213        NaN
# 1709292        NaN
# 1709293        NaN
#
# [224093 rows x 39 columns]

# %%
ddf[ddf['Temperature(F)'].isna()].compute()
# Out:
#          Severity          Start_Time  Start_Lat   Start_Lng         City  \
# 601             3 2016-03-11 07:28:40  41.323063  -82.616463        Milan
# 1734            2 2016-06-30 08:00:04  38.386948 -121.242165       Wilton
# 1957            2 2016-07-03 03:54:45  37.902588 -122.514198  Mill Valley
# 1968            2 2016-07-03 08:41:05  37.994217 -122.532051   San Rafael
# 1973            2 2016-07-03 11:59:28  37.993839 -122.532051   San Rafael
# ...           ...                 ...        ...         ...          ...
# 1709096         2 2019-08-23 12:23:00  40.705620 -111.546730    Park City
# 1709102         2 2019-08-23 13:23:00  40.792697 -111.450383    Coalville
# 1709157         2 2019-08-23 07:01:53  47.244171 -122.335366       Milton
# 1709190         2 2019-08-23 17:19:55  44.119763 -121.317222         Bend
# 1709245         2 2019-08-23 23:48:20  44.157060 -121.261170         Bend
#
#              County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 601            Erie    OH         KPCW             NaN            NaN  ...
# 1734     Sacramento    CA         KMHR             NaN            NaN  ...
# 1957          Marin    CA         KDVO             NaN            NaN  ...
# 1968          Marin    CA         KDVO             NaN            NaN  ...
# 1973          Marin    CA         KDVO             NaN            NaN  ...
# ...             ...   ...          ...             ...            ...  ...
# 1709096      Summit    UT         K36U             NaN            NaN  ...
# 1709102      Summit    UT         K36U             NaN            NaN  ...
# 1709157      Pierce    WA         KPLU             NaN            NaN  ...
# 1709190   Deschutes    OR         <NA>             NaN            NaN  ...
# 1709245   Deschutes    OR         <NA>             NaN            NaN  ...
#
#          Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 601             False             Day             Day               Day
# 1734            False             Day             Day               Day
# 1957            False           Night           Night             Night
# 1968            False             Day             Day               Day
# 1973            False             Day             Day               Day
# ...               ...             ...             ...               ...
# 1709096         False             Day             Day               Day
# 1709102         False             Day             Day               Day
# 1709157         False             Day             Day               Day
# 1709190         False             Day             Day               Day
# 1709245         False           Night           Night             Night
#
#          Astronomical_Twilight                        airport_name gps_code  \
# 601                        Day                 Carl R Keller Field     KPCW
# 1734                       Day           Sacramento Mather Airport     KMHR
# 1957                     Night  Marin County Airport - Gnoss Field     KDVO
# 1968                       Day  Marin County Airport - Gnoss Field     KDVO
# 1973                       Day  Marin County Airport - Gnoss Field     KDVO
# ...                        ...                                 ...      ...
# 1709096                    Day                                <NA>     <NA>
# 1709102                    Day                                <NA>     <NA>
# 1709157                    Day            Pierce County-Thun Field     KPLU
# 1709190                    Day         Los Alamitos Army Air Field     KSLI
# 1709245                  Night         Los Alamitos Army Air Field     KSLI
#
#          local_code   latitude   longitude
# 601             PCW  41.515647  -82.868328
# 1734            MHR  38.554744 -121.297989
# 1957            DVO  38.143600 -122.556000
# 1968            DVO  38.143600 -122.556000
# 1973            DVO  38.143600 -122.556000
# ...             ...        ...         ...
# 1709096        <NA>        NaN         NaN
# 1709102        <NA>        NaN         NaN
# 1709157         PLU  47.103901 -122.287003
# 1709190         SLI  33.790001 -118.052002
# 1709245         SLI  33.790001 -118.052002
#
# [163853 rows x 39 columns]

# %%
ddf = ddf.dropna(subset=['Airport_Code'])

# %%
ddf['airport_name'] = ddf['airport_name'].fillna('Unknown')

# %%
ddf.head()
# Out:
#    Severity          Start_Time  Start_Lat  Start_Lng          City  \
# 0         3 2016-02-08 05:46:00  39.865147 -84.058723        Dayton
# 1         2 2016-02-08 06:07:59  39.928059 -82.831184  Reynoldsburg
# 2         2 2016-02-08 06:49:27  39.063148 -84.032608  Williamsburg
# 3         3 2016-02-08 07:23:34  39.747753 -84.205582        Dayton
# 4         2 2016-02-08 07:39:07  39.627781 -84.188354        Dayton
#
#        County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 0  Montgomery    OH         KFFO            36.9            NaN  ...
# 1    Franklin    OH         KCMH            37.9            NaN  ...
# 2    Clermont    OH         KI69            36.0           33.3  ...
# 3  Montgomery    OH         KDAY            35.1           31.0  ...
# 4  Montgomery    OH         KMGY            36.0           33.3  ...
#
#    Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0         False           Night           Night             Night
# 1         False           Night           Night             Night
# 2         False           Night           Night               Day
# 3         False           Night             Day               Day
# 4         False             Day             Day               Day
#
#    Astronomical_Twilight                              airport_name gps_code  \
# 0                  Night           Wright-Patterson Air Force Base     KFFO
# 1                    Day                                   Unknown     <NA>
# 2                    Day                   Clermont County Airport     KI69
# 3                    Day  James M Cox Dayton International Airport     KDAY
# 4                    Day            Dayton-Wright Brothers Airport     KMGY
#
#    local_code   latitude  longitude
# 0         FFO  39.826099 -84.048302
# 1        <NA>        NaN        NaN
# 2         I69  39.078400 -84.210197
# 3         DAY  39.902401 -84.219398
# 4         MGY  39.589001 -84.224899
#
# [5 rows x 39 columns]

# %%
ddf.info()
# Out:
# <class 'dask.dataframe.dask_expr.DataFrame'>
# Columns: 39 entries, Severity to longitude
# dtypes: datetime64[ns](1), object(13), float64(12), string(13)

# %%
ddf = ddf.reset_index(drop=True)

# %%
ddf.head()
# Out:
#    Severity          Start_Time  Start_Lat  Start_Lng          City  \
# 0         3 2016-02-08 05:46:00  39.865147 -84.058723        Dayton
# 1         2 2016-02-08 06:07:59  39.928059 -82.831184  Reynoldsburg
# 2         2 2016-02-08 06:49:27  39.063148 -84.032608  Williamsburg
# 3         3 2016-02-08 07:23:34  39.747753 -84.205582        Dayton
# 4         2 2016-02-08 07:39:07  39.627781 -84.188354        Dayton
#
#        County State Airport_Code  Temperature(F)  Wind_Chill(F)  ...  \
# 0  Montgomery    OH         KFFO            36.9            NaN  ...
# 1    Franklin    OH         KCMH            37.9            NaN  ...
# 2    Clermont    OH         KI69            36.0           33.3  ...
# 3  Montgomery    OH         KDAY            35.1           31.0  ...
# 4  Montgomery    OH         KMGY            36.0           33.3  ...
#
#    Turning_Loop  Sunrise_Sunset  Civil_Twilight Nautical_Twilight  \
# 0         False           Night           Night             Night
# 1         False           Night           Night             Night
# 2         False           Night           Night               Day
# 3         False           Night             Day               Day
# 4         False             Day             Day               Day
#
#    Astronomical_Twilight                              airport_name gps_code  \
# 0                  Night           Wright-Patterson Air Force Base     KFFO
# 1                    Day                                   Unknown     <NA>
# 2                    Day                   Clermont County Airport     KI69
# 3                    Day  James M Cox Dayton International Airport     KDAY
# 4                    Day            Dayton-Wright Brothers Airport     KMGY
#
#    local_code   latitude  longitude
# 0         FFO  39.826099 -84.048302
# 1        <NA>        NaN        NaN
# 2         I69  39.078400 -84.210197
# 3         DAY  39.902401 -84.219398
# 4         MGY  39.589001 -84.224899
#
# [5 rows x 39 columns]

# %%
ddf.info()
# Out:
# <class 'dask.dataframe.dask_expr.DataFrame'>
# Columns: 39 entries, Severity to longitude
# dtypes: datetime64[ns](1), object(13), float64(12), string(13)

# %%
weather_cols = [
    'Temperature(F)','Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 
    'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)'
]

# %%
ddf.columns
# Out:
# Index(['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'County',
#        'State', 'Airport_Code', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'airport_name', 'gps_code', 'local_code',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
global_medians = {}
for col in weather_cols:
    try:
        global_medians[col] = ddf[col].quantile(0.5).compute()
    except:
        global_medians[col] = ddf[col].dropna().compute().median()

# Apply both group-wise and global median filling in sequence
for col in weather_cols:
    # First: group-wise median filling
    ddf[col] = ddf.groupby('Airport_Code')[col].transform(
        lambda x: x.fillna(x.median()),
        meta=(col, 'f8')
    )
    
    # Second: global median for any remaining NaNs
    ddf[col] = ddf[col].fillna(global_medians[col])

# Check if any missing values are left
print("Missing values after filling:")
print(ddf[weather_cols].isnull().sum().compute())
# Out:
# Missing values after filling:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[332], line 21
#      19 # Check if any missing values are left
#      20 print("Missing values after filling:")
# ---> 21 print(ddf[weather_cols].isnull().sum().compute())
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\base.py:373, in DaskMethodsMixin.compute(self, **kwargs)
#     349 def compute(self, **kwargs):
#     350     """Compute this dask collection
#     351
#     352     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    371     dask.compute
#     372     """
# --> 373     (result,) = compute(self, traverse=False, **kwargs)
#     374     return result
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\dataframe\dask_expr\_expr.py:1953, in assign(df, *pairs)
#    1951         if isinstance(val, Callable):
#    1952             val = val(df)
# -> 1953         df[name] = val
#    1954 return df
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\pandas\core\indexes\base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
ddf_f = ddf.reset_index(drop=True)

# %%
ddf_f.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[296], line 1
# ----> 1 ddf_f.head()
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\dataframe\dask_expr\_collection.py:692, in FrameBase.head(self, n, npartitions, compute)
#     690 out = new_collection(expr.Head(self, n=n, npartitions=npartitions))
#     691 if compute:
# --> 692     out = out.compute()
#     693 return out
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\base.py:373, in DaskMethodsMixin.compute(self, **kwargs)
#     349 def compute(self, **kwargs):
#     350     """Compute this dask collection
#     351
#     352     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    371     dask.compute
#     372     """
# --> 373     (result,) = compute(self, traverse=False, **kwargs)
#     374     return result
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     678     expr = expr.optimize()
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\dask\dataframe\dask_expr\_expr.py:1953, in assign(df, *pairs)
#    1951         if isinstance(val, Callable):
#    1952             val = val(df)
# -> 1953         df[name] = val
#    1954 return df
#
# File c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\pandas\core\indexes\base.py:4436, in Index.reindex(self, target, method, level, limit, tolerance)
#    4433     raise ValueError("cannot handle a non-unique multi-index!")
#    4434 elif not self.is_unique:
#    4435     # GH#42568
# -> 4436     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4437 else:
#    4438     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
print("Missing values after filling:")
print(ddf[weather_cols].isnull().sum().compute())
