# %%
import pandas as pd
import numpy as np
import pyarrow
import dask.dataframe as dd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_parquet('../data/us_accidents.parquet')
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  \
# 0  39.865147 -84.058723      NaN      NaN          0.01
# 1  39.928059 -82.831184      NaN      NaN          0.01
# 2  39.063148 -84.032608      NaN      NaN          0.01
# 3  39.747753 -84.205582      NaN      NaN          0.01
# 4  39.627781 -84.188354      NaN      NaN          0.01
#
#                                          Description  \
# 0  Right lane blocked due to accident on I-70 Eas...
# 1  Accident on Brice Rd at Tussing Rd. Expect del...
# 2  Accident on OH-32 State Route 32 Westbound at ...
# 3  Accident on I-75 Southbound at Exits 52 52B US...
# 4  Accident on McEwen Rd at OH-725 Miamisburg Cen...
#
#                       Street          City      County State     Zipcode  \
# 0                     I-70 E        Dayton  Montgomery    OH       45424
# 1                   Brice Rd  Reynoldsburg    Franklin    OH  43068-3402
# 2             State Route 32  Williamsburg    Clermont    OH       45176
# 3                     I-75 S        Dayton  Montgomery    OH       45417
# 4  Miamisburg Centerville Rd        Dayton  Montgomery    OH       45459
#
#   Country    Timezone Airport_Code    Weather_Timestamp  Temperature(F)  \
# 0      US  US/Eastern         KFFO  2016-02-08 05:58:00            36.9
# 1      US  US/Eastern         KCMH  2016-02-08 05:51:00            37.9
# 2      US  US/Eastern         KI69  2016-02-08 06:56:00            36.0
# 3      US  US/Eastern         KDAY  2016-02-08 07:38:00            35.1
# 4      US  US/Eastern         KMGY  2016-02-08 07:53:00            36.0
#
#    Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 0            NaN         91.0         29.68            10.0           Calm
# 1            NaN        100.0         29.65            10.0           Calm
# 2           33.3        100.0         29.67            10.0             SW
# 3           31.0         96.0         29.64             9.0             SW
# 4           33.3         89.0         29.65             6.0             SW
#
#    Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 0              NaN               0.02        Light Rain    False  False
# 1              NaN               0.00        Light Rain    False  False
# 2              3.5                NaN          Overcast    False  False
# 3              4.6                NaN     Mostly Cloudy    False  False
# 4              3.5                NaN     Mostly Cloudy    False  False
#
#    Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0     False     False     False    False    False       False    False  False
# 1     False     False     False    False    False       False    False  False
# 2     False     False     False    False    False       False    False  False
# 3     False     False     False    False    False       False    False  False
# 4     False     False     False    False    False       False    False  False
#
#    Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0            False           False         False          Night
# 1            False           False         False          Night
# 2            False            True         False          Night
# 3            False           False         False          Night
# 4            False            True         False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
df.drop(columns=['ID', 'Source', 'Distance(mi)', 'End_Time', 'Duration', 'End_Lat', 'End_Lng', 'Description','Country', 'Street', 'Weather_Timestamp', 'Timezone', 'Zipcode'], inplace = True , errors='ignore')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 34 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Severity               int64
#  1   Start_Time             object
#  2   Start_Lat              float64
#  3   Start_Lng              float64
#  4   City                   object
#  5   County                 object
#  6   State                  object
#  7   Airport_Code           object
#  8   Temperature(F)         float64
#  9   Wind_Chill(F)          float64
#  10  Humidity(%)            float64
#  11  Pressure(in)           float64
#  12  Visibility(mi)         float64
#  13  Wind_Direction         object
#  14  Wind_Speed(mph)        float64
#  15  Precipitation(in)      float64
#  16  Weather_Condition      object
#  17  Amenity                bool
#  18  Bump                   bool
#  19  Crossing               bool
#  20  Give_Way               bool
#  21  Junction               bool
#  22  No_Exit                bool
#  23  Railway                bool
#  24  Roundabout             bool
#  25  Station                bool
#  26  Stop                   bool
#  27  Traffic_Calming        bool
#  28  Traffic_Signal         bool
#  29  Turning_Loop           bool
#  30  Sunrise_Sunset         object
#  31  Civil_Twilight         object
#  32  Nautical_Twilight      object
#  33  Astronomical_Twilight  object
# dtypes: bool(13), float64(9), int64(1), object(11)
# memory usage: 1.3+ GB

# %%
df_airports = pd.read_csv('../data/data-world-us-airports.csv')
df_airports
# Out:
#             ident           type                        name  elevation_ft  \
# 0             00A       heliport           Total RF Heliport          11.0
# 1            00AA  small_airport        Aero B Ranch Airport        3435.0
# 2            00AK  small_airport                Lowell Field         450.0
# 3            00AL  small_airport                Epps Airpark         820.0
# 4            00AN  small_airport        Katmai Lodge Airport          80.0
# ...           ...            ...                         ...           ...
# 48717   200000000  small_airport         Cackleberry Airport         890.0
# 48718    30000000  small_airport  Pronger Bros Ranch Airport        3722.0
# 48719   400000000  small_airport          Richardton Airport        2492.0
# 48720  5000000000  small_airport              Packer Airport         918.0
# 48721        7000  small_airport               Mills Airport        1140.0
#
#       continent iso_country iso_region  municipality icao_code iata_code  \
# 0           NaN          US      US-PA      Bensalem       NaN       NaN
# 1           NaN          US      US-KS         Leoti       NaN       NaN
# 2           NaN          US      US-AK  Anchor Point       NaN       NaN
# 3           NaN          US      US-AL       Harvest       NaN       NaN
# 4           NaN          US      US-AK   King Salmon       NaN       NaN
# ...         ...         ...        ...           ...       ...       ...
# 48717       NaN          US      US-MI        Dexter       NaN       NaN
# 48718       NaN          US      US-TX     Stratford       NaN       NaN
# 48719       NaN          US      US-ND    Richardton       NaN       NaN
# 48720       NaN          US      US-OH        Radnor       NaN       NaN
# 48721       NaN          US      US-OH       Ravenna       NaN       NaN
#
#         gps_code  local_code                            coordinates
# 0           K00A         00A                  40.070985, -74.933689
# 1           00AA        00AA                 38.704022, -101.473911
# 2           00AK        00AK                 59.947733, -151.692524
# 3           00AL        00AL  34.86479949951172, -86.77030181884766
# 4           00AN        00AN                 59.093287, -156.456699
# ...          ...         ...                                    ...
# 48717  200000000   200000000                    42.424999, -83.8694
# 48718   30000000    30000000                 36.219501, -102.103996
# 48719  400000000   400000000  46.89580154418945, -102.3550033569336
# 48720       K5E9  5000000000                  40.407854, -83.215183
# 48721        NaN        7000                    41.2384, -81.253799
#
# [48722 rows x 13 columns]

# %%
df_airports.drop(columns=['type', 'elevation_ft', 'continent', 'iso_country', 'iso_region', 'municipality', 'icao_code', 'iata_code'], inplace=True, errors='ignore')
df_airports[['latitude', 'longitude']] = df_airports['coordinates'].str.split(',', expand=True)
df_airports['latitude'] = df_airports['latitude'].astype(float)
df_airports['longitude'] = df_airports['longitude'].astype(float)
df_airports.drop(columns = ['coordinates'], inplace=True, errors='ignore')
df_airports.rename(columns={'ident': 'Airport_Code', 'name':'airport_name'}, inplace=True, errors='ignore')

# %%
df = df.merge(df_airports, how='left', left_on='Airport_Code', right_on='Airport_Code', suffixes=('', '_airport'))

# %%
df[df['airport_name'].isna() & df['Airport_Code'].notna()]
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng  \
# 42863           2  2016-06-21 10:38:47  34.267788 -118.644249
# 42866           2  2016-06-21 10:46:30  34.078926 -118.289040
# 42867           3  2016-06-21 10:49:21  34.091179 -118.239471
# 42868           3  2016-06-21 10:46:04  34.207294 -118.216927
# 42879           3  2016-06-21 10:50:48  34.339706 -118.506447
# ...           ...                  ...        ...         ...
# 7728352         4  2019-08-23 17:01:58  40.374860 -120.399344
# 7728353         4  2019-08-23 17:01:58  40.370829 -120.400948
# 7728357         3  2019-08-23 04:04:48  34.075790 -118.276680
# 7728361         2  2019-08-23 12:52:31  34.023790 -118.276390
# 7728364         2  2019-08-23 13:42:50  34.070610 -118.263910
#
#                          City       County State Airport_Code  Temperature(F)  \
# 42863             Simi Valley      Ventura    CA         K3A6            87.0
# 42866             Los Angeles  Los Angeles    CA         KCQT            82.9
# 42867             Los Angeles  Los Angeles    CA         KCQT            82.9
# 42868    La Canada Flintridge  Los Angeles    CA         KMWS             NaN
# 42879                 Newhall  Los Angeles    CA         K3A6            87.0
# ...                       ...          ...   ...          ...             ...
# 7728352            Susanville       Lassen    CA         KRTS            90.0
# 7728353            Susanville       Lassen    CA         KRTS            90.0
# 7728357           Los Angeles  Los Angeles    CA         KCQT            67.0
# 7728361           Los Angeles  Los Angeles    CA         KCQT            81.0
# 7728364           Los Angeles  Los Angeles    CA         KCQT            82.0
#
#          Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 42863             87.0         35.0         29.11            10.0
# 42866              NaN         47.0         29.95            10.0
# 42867              NaN         47.0         29.95            10.0
# 42868              NaN          NaN           NaN             NaN
# 42879             87.0         35.0         29.11            10.0
# ...                ...          ...           ...             ...
# 7728352           90.0         17.0         24.91            10.0
# 7728353           90.0         17.0         24.91            10.0
# 7728357           67.0         79.0         29.62             7.0
# 7728361           81.0         49.0         29.66             8.0
# 7728364           82.0         47.0         29.65             9.0
#
#         Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 42863              SSE              8.0                0.0              Fair
# 42866         Variable              4.6                NaN             Clear
# 42867         Variable              4.6                NaN             Clear
# 42868             None              NaN                NaN              None
# 42879              SSE              8.0                0.0              Fair
# ...                ...              ...                ...               ...
# 7728352            VAR              7.0                0.0              Fair
# 7728353            VAR              7.0                0.0              Fair
# 7728357           CALM              0.0                0.0            Cloudy
# 7728361           CALM              0.0                0.0              Fair
# 7728364           CALM              0.0                0.0              Fair
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 42863      False  False     False     False     False    False    False
# 42866      False  False     False     False      True    False    False
# 42867      False  False     False     False     False    False    False
# 42868      False  False     False     False     False    False    False
# 42879      False  False     False     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 7728352    False  False     False     False     False    False    False
# 7728353    False  False     False     False     False    False    False
# 7728357    False  False     False     False     False    False    False
# 7728361    False  False     False     False     False    False    False
# 7728364    False  False     False     False      True    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 42863         False    False  False            False           False
# 42866         False    False  False            False           False
# 42867         False    False  False            False           False
# 42868         False    False  False            False           False
# 42879         False    False  False            False           False
# ...             ...      ...    ...              ...             ...
# 7728352       False    False  False            False           False
# 7728353       False    False  False            False           False
# 7728357       False    False  False            False           False
# 7728361       False    False  False            False           False
# 7728364       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 42863           False            Day            Day               Day
# 42866           False            Day            Day               Day
# 42867           False            Day            Day               Day
# 42868           False            Day            Day               Day
# 42879           False            Day            Day               Day
# ...               ...            ...            ...               ...
# 7728352         False            Day            Day               Day
# 7728353         False            Day            Day               Day
# 7728357         False          Night          Night             Night
# 7728361         False            Day            Day               Day
# 7728364         False            Day            Day               Day
#
#         Astronomical_Twilight airport_name gps_code local_code  latitude  \
# 42863                     Day          NaN      NaN        NaN       NaN
# 42866                     Day          NaN      NaN        NaN       NaN
# 42867                     Day          NaN      NaN        NaN       NaN
# 42868                     Day          NaN      NaN        NaN       NaN
# 42879                     Day          NaN      NaN        NaN       NaN
# ...                       ...          ...      ...        ...       ...
# 7728352                   Day          NaN      NaN        NaN       NaN
# 7728353                   Day          NaN      NaN        NaN       NaN
# 7728357                 Night          NaN      NaN        NaN       NaN
# 7728361                   Day          NaN      NaN        NaN       NaN
# 7728364                   Day          NaN      NaN        NaN       NaN
#
#          longitude
# 42863          NaN
# 42866          NaN
# 42867          NaN
# 42868          NaN
# 42879          NaN
# ...            ...
# 7728352        NaN
# 7728353        NaN
# 7728357        NaN
# 7728361        NaN
# 7728364        NaN
#
# [562771 rows x 39 columns]

# %%
airport_corrections = {
    'KCQT': {
        'airport_name': 'Whiteman Airport',
        'latitude': 34.2598,
        'longitude': -118.4119
    },
    'KMCJ': {
        'airport_name': 'William P Hobby Airport',
        'latitude': 29.6459,
        'longitude': -95.2769
    },
    'KATT': {
        'airport_name': 'Austin–Bergstrom International Airport',
        'latitude': 30.197535,
        'longitude': -97.662015
    },
    'KJRB': {
        'airport_name': 'Downtown Manhattan Heliport',
        'latitude': 40.700711,
        'longitude': -74.008573
    },
    'KDMH': {
        'airport_name': 'Baltimore/Washington International Airport',
        'latitude': 39.1718,
        'longitude': -76.6677
    }

}

# %%
for code, info in airport_corrections.items():
    mask = df['Airport_Code'] == code

    df.loc[mask, 'airport_name'] = info['airport_name']
    df.loc[mask, 'latitude'] = info['latitude']
    df.loc[mask, 'longitude'] = info['longitude']

# %%
df[df['airport_name'].isna()]['Airport_Code'].value_counts()
# Out:
# Airport_Code
# KNYC    24649
# K3A6    19046
# KAUD    17034
# KMWS    12349
# KNKA    11155
#         ...
# K7R5        1
# KP58        1
# KAXO        1
# KPAT        1
# KY22        1
# Name: count, Length: 163, dtype: int64

# %%
conditional_airport_data = {
    'KNYC': {
        'Kings': {
            'airport_name': 'John F. Kennedy International Airport (JFK)',
            'latitude': 40.64013,
            'longitude': -73.77651
        },
        'New York': {
            'airport_name': 'LaGuardia Airport (LGA)',
            'latitude': 40.7769,
            'longitude': -73.8740
        },
        'Hudson': {
            'airport_name': 'Newark Liberty International Airport (EWR)',
            'latitude': 40.6925,
            'longitude': -74.1687
        },
        'Queens': {
            'airport_name': 'John F. Kennedy International Airport (JFK)',
            'latitude': 40.64013,
            'longitude': -73.77651
        },
        'Bergen': {
            'airport_name': 'Teterboro Airport (TEB)',
            'latitude': 40.8502,
            'longitude': -74.0609
        }
    }
}

# %%
for code, county_map in conditional_airport_data.items():
    for county, info in county_map.items():
        mask = (df['Airport_Code'] == code) & (df['County'] == county)

        for col, value in info.items():
            df.loc[mask, col] = value

# %%
df[df['airport_name'].isna() & df['Airport_Code'].notna()]
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng  \
# 42863           2  2016-06-21 10:38:47  34.267788 -118.644249
# 42868           3  2016-06-21 10:46:04  34.207294 -118.216927
# 42879           3  2016-06-21 10:50:48  34.339706 -118.506447
# 42926           2  2016-06-21 12:16:31  34.227718 -118.185913
# 42927           2  2016-06-21 12:21:46  34.143398 -118.170792
# ...           ...                  ...        ...         ...
# 7728211         2  2019-08-23 01:59:56  42.430325 -123.252602
# 7728262         2  2019-08-23 12:20:38  42.437790 -123.285592
# 7728273         2  2019-08-23 12:52:07  45.460548 -123.803174
# 7728352         4  2019-08-23 17:01:58  40.374860 -120.399344
# 7728353         4  2019-08-23 17:01:58  40.370829 -120.400948
#
#                          City       County State Airport_Code  Temperature(F)  \
# 42863             Simi Valley      Ventura    CA         K3A6            87.0
# 42868    La Canada Flintridge  Los Angeles    CA         KMWS             NaN
# 42879                 Newhall  Los Angeles    CA         K3A6            87.0
# 42926    La Canada Flintridge  Los Angeles    CA         KMWS             NaN
# 42927                Pasadena  Los Angeles    CA         KMWS             NaN
# ...                       ...          ...   ...          ...             ...
# 7728211           Grants Pass    Josephine    OR         KSXT            58.0
# 7728262           Grants Pass    Josephine    OR         KSXT            70.0
# 7728273             Tillamook    Tillamook    OR         KS47            70.0
# 7728352            Susanville       Lassen    CA         KRTS            90.0
# 7728353            Susanville       Lassen    CA         KRTS            90.0
#
#          Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 42863             87.0         35.0         29.11            10.0
# 42868              NaN          NaN           NaN             NaN
# 42879             87.0         35.0         29.11            10.0
# 42926              NaN          NaN           NaN             NaN
# 42927              NaN          NaN           NaN             NaN
# ...                ...          ...           ...             ...
# 7728211           58.0         84.0         26.06            10.0
# 7728262           70.0         61.0         26.07            10.0
# 7728273           70.0         60.0         29.92            10.0
# 7728352           90.0         17.0         24.91            10.0
# 7728353           90.0         17.0         24.91            10.0
#
#         Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 42863              SSE              8.0                0.0              Fair
# 42868             None              NaN                NaN              None
# 42879              SSE              8.0                0.0              Fair
# 42926             None              NaN                NaN              None
# 42927             None              NaN                NaN              None
# ...                ...              ...                ...               ...
# 7728211            ENE              3.0                0.0              Fair
# 7728262           CALM              0.0                0.0              Fair
# 7728273            WNW              5.0                0.0              Fair
# 7728352            VAR              7.0                0.0              Fair
# 7728353            VAR              7.0                0.0              Fair
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 42863      False  False     False     False     False    False    False
# 42868      False  False     False     False     False    False    False
# 42879      False  False     False     False     False    False    False
# 42926      False  False     False     False     False    False    False
# 42927      False  False     False     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 7728211    False  False     False     False     False    False    False
# 7728262    False  False     False     False     False    False    False
# 7728273    False  False     False     False     False    False    False
# 7728352    False  False     False     False     False    False    False
# 7728353    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 42863         False    False  False            False           False
# 42868         False    False  False            False           False
# 42879         False    False  False            False           False
# 42926         False    False  False            False           False
# 42927         False    False  False            False           False
# ...             ...      ...    ...              ...             ...
# 7728211       False    False  False            False           False
# 7728262       False    False  False            False           False
# 7728273       False    False  False            False           False
# 7728352       False    False  False            False           False
# 7728353       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 42863           False            Day            Day               Day
# 42868           False            Day            Day               Day
# 42879           False            Day            Day               Day
# 42926           False            Day            Day               Day
# 42927           False            Day            Day               Day
# ...               ...            ...            ...               ...
# 7728211         False          Night          Night             Night
# 7728262         False            Day            Day               Day
# 7728273         False            Day            Day               Day
# 7728352         False            Day            Day               Day
# 7728353         False            Day            Day               Day
#
#         Astronomical_Twilight airport_name gps_code local_code  latitude  \
# 42863                     Day          NaN      NaN        NaN       NaN
# 42868                     Day          NaN      NaN        NaN       NaN
# 42879                     Day          NaN      NaN        NaN       NaN
# 42926                     Day          NaN      NaN        NaN       NaN
# 42927                     Day          NaN      NaN        NaN       NaN
# ...                       ...          ...      ...        ...       ...
# 7728211                 Night          NaN      NaN        NaN       NaN
# 7728262                   Day          NaN      NaN        NaN       NaN
# 7728273                   Day          NaN      NaN        NaN       NaN
# 7728352                   Day          NaN      NaN        NaN       NaN
# 7728353                   Day          NaN      NaN        NaN       NaN
#
#          longitude
# 42863          NaN
# 42868          NaN
# 42879          NaN
# 42926          NaN
# 42927          NaN
# ...            ...
# 7728211        NaN
# 7728262        NaN
# 7728273        NaN
# 7728352        NaN
# 7728353        NaN
#
# [202276 rows x 39 columns]

# %%
df[df['Temperature(F)'].isna()]
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng         City  \
# 601             3  2016-03-11 07:28:40  41.323063  -82.616463        Milan
# 1734            2  2016-06-30 08:00:04  38.386948 -121.242165       Wilton
# 1957            2  2016-07-03 03:54:45  37.902588 -122.514198  Mill Valley
# 1968            2  2016-07-03 08:41:05  37.994217 -122.532051   San Rafael
# 1973            2  2016-07-03 11:59:28  37.993839 -122.532051   San Rafael
# ...           ...                  ...        ...         ...          ...
# 7728156         2  2019-08-23 12:23:00  40.705620 -111.546730    Park City
# 7728162         2  2019-08-23 13:23:00  40.792697 -111.450383    Coalville
# 7728217         2  2019-08-23 07:01:53  47.244171 -122.335366       Milton
# 7728250         2  2019-08-23 17:19:55  44.119763 -121.317222         Bend
# 7728305         2  2019-08-23 23:48:20  44.157060 -121.261170         Bend
#
#              County State Airport_Code  Temperature(F)  Wind_Chill(F)  \
# 601            Erie    OH         KPCW             NaN            NaN
# 1734     Sacramento    CA         KMHR             NaN            NaN
# 1957          Marin    CA         KDVO             NaN            NaN
# 1968          Marin    CA         KDVO             NaN            NaN
# 1973          Marin    CA         KDVO             NaN            NaN
# ...             ...   ...          ...             ...            ...
# 7728156      Summit    UT         K36U             NaN            NaN
# 7728162      Summit    UT         K36U             NaN            NaN
# 7728217      Pierce    WA         KPLU             NaN            NaN
# 7728250   Deschutes    OR         None             NaN            NaN
# 7728305   Deschutes    OR         None             NaN            NaN
#
#          Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 601              NaN           NaN             NaN           None
# 1734             NaN         29.86            10.0           Calm
# 1957             NaN           NaN             NaN           None
# 1968             NaN           NaN             NaN           None
# 1973             NaN           NaN             NaN           None
# ...              ...           ...             ...            ...
# 7728156          NaN           NaN             NaN           None
# 7728162          NaN           NaN             NaN           None
# 7728217          NaN         29.65            10.0            ESE
# 7728250          NaN           NaN             NaN           None
# 7728305          NaN           NaN             NaN           None
#
#          Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 601                  NaN                NaN              None    False  False
# 1734                 NaN                NaN             Clear    False  False
# 1957                 NaN                NaN              None    False  False
# 1968                 NaN                NaN              None    False  False
# 1973                 NaN                NaN              None    False  False
# ...                  ...                ...               ...      ...    ...
# 7728156              NaN                NaN              None    False  False
# 7728162              NaN                NaN              None    False  False
# 7728217              1.0                0.0     Partly Cloudy    False  False
# 7728250              NaN                NaN              None    False  False
# 7728305              NaN                NaN              None    False  False
#
#          Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station  \
# 601         False     False     False    False    False       False    False
# 1734        False     False     False    False    False       False    False
# 1957         True     False     False    False    False       False    False
# 1968        False     False     False    False    False       False    False
# 1973        False     False     False    False    False       False    False
# ...           ...       ...       ...      ...      ...         ...      ...
# 7728156      True     False     False    False    False       False    False
# 7728162     False     False     False    False    False       False    False
# 7728217     False     False     False    False    False       False    False
# 7728250     False     False     False    False    False       False    False
# 7728305     False     False     False    False    False       False    False
#
#           Stop  Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 601      False            False           False         False            Day
# 1734     False            False           False         False            Day
# 1957     False            False            True         False          Night
# 1968     False            False           False         False            Day
# 1973     False            False           False         False            Day
# ...        ...              ...             ...           ...            ...
# 7728156  False            False           False         False            Day
# 7728162  False            False           False         False            Day
# 7728217  False            False           False         False            Day
# 7728250  False            False           False         False            Day
# 7728305  False            False           False         False          Night
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 601                Day               Day                   Day
# 1734               Day               Day                   Day
# 1957             Night             Night                 Night
# 1968               Day               Day                   Day
# 1973               Day               Day                   Day
# ...                ...               ...                   ...
# 7728156            Day               Day                   Day
# 7728162            Day               Day                   Day
# 7728217            Day               Day                   Day
# 7728250            Day               Day                   Day
# 7728305          Night             Night                 Night
#
#                                airport_name gps_code local_code   latitude  \
# 601                     Carl R Keller Field     KPCW        PCW  41.515647
# 1734              Sacramento Mather Airport     KMHR        MHR  38.554744
# 1957     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# 1968     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# 1973     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# ...                                     ...      ...        ...        ...
# 7728156                                 NaN      NaN        NaN        NaN
# 7728162                                 NaN      NaN        NaN        NaN
# 7728217            Pierce County-Thun Field     KPLU        PLU  47.103901
# 7728250                                 NaN      NaN        NaN        NaN
# 7728305                                 NaN      NaN        NaN        NaN
#
#           longitude
# 601      -82.868328
# 1734    -121.297989
# 1957    -122.556000
# 1968    -122.556000
# 1973    -122.556000
# ...             ...
# 7728156         NaN
# 7728162         NaN
# 7728217 -122.287003
# 7728250         NaN
# 7728305         NaN
#
# [163853 rows x 39 columns]

# %%
df.dropna(subset=['Airport_Code'], inplace=True)

# %%
df.columns
# Out:
# Index(['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'County',
#        'State', 'Airport_Code', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'airport_name', 'gps_code', 'local_code',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
df[df['Temperature(F)'].isna()]
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng         City  \
# 601             3  2016-03-11 07:28:40  41.323063  -82.616463        Milan
# 1734            2  2016-06-30 08:00:04  38.386948 -121.242165       Wilton
# 1957            2  2016-07-03 03:54:45  37.902588 -122.514198  Mill Valley
# 1968            2  2016-07-03 08:41:05  37.994217 -122.532051   San Rafael
# 1973            2  2016-07-03 11:59:28  37.993839 -122.532051   San Rafael
# ...           ...                  ...        ...         ...          ...
# 7728153         2  2019-08-23 12:00:00  38.420326 -111.666818          Loa
# 7728155         2  2019-08-23 12:23:00  40.703698 -111.546392    Park City
# 7728156         2  2019-08-23 12:23:00  40.705620 -111.546730    Park City
# 7728162         2  2019-08-23 13:23:00  40.792697 -111.450383    Coalville
# 7728217         2  2019-08-23 07:01:53  47.244171 -122.335366       Milton
#
#              County State Airport_Code  Temperature(F)  Wind_Chill(F)  \
# 601            Erie    OH         KPCW             NaN            NaN
# 1734     Sacramento    CA         KMHR             NaN            NaN
# 1957          Marin    CA         KDVO             NaN            NaN
# 1968          Marin    CA         KDVO             NaN            NaN
# 1973          Marin    CA         KDVO             NaN            NaN
# ...             ...   ...          ...             ...            ...
# 7728153       Wayne    UT         K4HV             NaN            NaN
# 7728155      Summit    UT         K36U             NaN            NaN
# 7728156      Summit    UT         K36U             NaN            NaN
# 7728162      Summit    UT         K36U             NaN            NaN
# 7728217      Pierce    WA         KPLU             NaN            NaN
#
#          Humidity(%)  Pressure(in)  Visibility(mi) Wind_Direction  \
# 601              NaN           NaN             NaN           None
# 1734             NaN         29.86            10.0           Calm
# 1957             NaN           NaN             NaN           None
# 1968             NaN           NaN             NaN           None
# 1973             NaN           NaN             NaN           None
# ...              ...           ...             ...            ...
# 7728153          NaN           NaN             NaN           None
# 7728155          NaN           NaN             NaN           None
# 7728156          NaN           NaN             NaN           None
# 7728162          NaN           NaN             NaN           None
# 7728217          NaN         29.65            10.0            ESE
#
#          Wind_Speed(mph)  Precipitation(in) Weather_Condition  Amenity   Bump  \
# 601                  NaN                NaN              None    False  False
# 1734                 NaN                NaN             Clear    False  False
# 1957                 NaN                NaN              None    False  False
# 1968                 NaN                NaN              None    False  False
# 1973                 NaN                NaN              None    False  False
# ...                  ...                ...               ...      ...    ...
# 7728153              NaN                NaN              None    False  False
# 7728155              NaN                NaN              None    False  False
# 7728156              NaN                NaN              None    False  False
# 7728162              NaN                NaN              None    False  False
# 7728217              1.0                0.0     Partly Cloudy    False  False
#
#          Crossing  Give_Way  Junction  No_Exit  Railway  Roundabout  Station  \
# 601         False     False     False    False    False       False    False
# 1734        False     False     False    False    False       False    False
# 1957         True     False     False    False    False       False    False
# 1968        False     False     False    False    False       False    False
# 1973        False     False     False    False    False       False    False
# ...           ...       ...       ...      ...      ...         ...      ...
# 7728153     False     False     False    False    False       False    False
# 7728155     False     False     False    False    False       False    False
# 7728156      True     False     False    False    False       False    False
# 7728162     False     False     False    False    False       False    False
# 7728217     False     False     False    False    False       False    False
#
#           Stop  Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 601      False            False           False         False            Day
# 1734     False            False           False         False            Day
# 1957     False            False            True         False          Night
# 1968     False            False           False         False            Day
# 1973     False            False           False         False            Day
# ...        ...              ...             ...           ...            ...
# 7728153  False            False           False         False            Day
# 7728155  False            False           False         False            Day
# 7728156  False            False           False         False            Day
# 7728162  False            False           False         False            Day
# 7728217  False            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 601                Day               Day                   Day
# 1734               Day               Day                   Day
# 1957             Night             Night                 Night
# 1968               Day               Day                   Day
# 1973               Day               Day                   Day
# ...                ...               ...                   ...
# 7728153            Day               Day                   Day
# 7728155            Day               Day                   Day
# 7728156            Day               Day                   Day
# 7728162            Day               Day                   Day
# 7728217            Day               Day                   Day
#
#                                airport_name gps_code local_code   latitude  \
# 601                     Carl R Keller Field     KPCW        PCW  41.515647
# 1734              Sacramento Mather Airport     KMHR        MHR  38.554744
# 1957     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# 1968     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# 1973     Marin County Airport - Gnoss Field     KDVO        DVO  38.143600
# ...                                     ...      ...        ...        ...
# 7728153                                 NaN      NaN        NaN        NaN
# 7728155                                 NaN      NaN        NaN        NaN
# 7728156                                 NaN      NaN        NaN        NaN
# 7728162                                 NaN      NaN        NaN        NaN
# 7728217            Pierce County-Thun Field     KPLU        PLU  47.103901
#
#           longitude
# 601      -82.868328
# 1734    -121.297989
# 1957    -122.556000
# 1968    -122.556000
# 1973    -122.556000
# ...             ...
# 7728153         NaN
# 7728155         NaN
# 7728156         NaN
# 7728162         NaN
# 7728217 -122.287003
#
# [141218 rows x 39 columns]

# %%
df['airport_name'].fillna('Unknown', inplace=True)
# Out:
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3521453827.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['airport_name'].fillna('Unknown', inplace=True)

# %%
weather_cols = [
    'Temperature(F)','Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 
    'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)'
]

# %%
for col in weather_cols:
    df[col] = df.groupby('Airport_Code')[col].transform(lambda x: x.fillna(x.median()))

for col in weather_cols:
    df[col].fillna(df[col].median(), inplace=True)

print("Missing values after filling:")
print(df[weather_cols].isnull().sum())
# Out:
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\saqui\TensorVault\ZoyaProjectCode\us-accidents-thesis\venv-z\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1214: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# C:\Users\saqui\AppData\Local\Temp\ipykernel_11984\3564981861.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# Missing values after filling:
# Temperature(F)       0
# Wind_Chill(F)        0
# Humidity(%)          0
# Pressure(in)         0
# Visibility(mi)       0
# Wind_Speed(mph)      0
# Precipitation(in)    0
# dtype: int64

# %%
df.drop(columns=['Airport_Code', 'gps_code', 'local_code'], inplace=True, errors='ignore')
df.rename(columns={'latitude': 'airport_latitude', 'longitude': 'airport_longitude'}, inplace=True, errors='ignore')

# %%
df
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng          City  \
# 0               3  2016-02-08 05:46:00  39.865147  -84.058723        Dayton
# 1               2  2016-02-08 06:07:59  39.928059  -82.831184  Reynoldsburg
# 2               2  2016-02-08 06:49:27  39.063148  -84.032608  Williamsburg
# 3               3  2016-02-08 07:23:34  39.747753  -84.205582        Dayton
# 4               2  2016-02-08 07:39:07  39.627781  -84.188354        Dayton
# ...           ...                  ...        ...         ...           ...
# 7728389         2  2019-08-23 18:03:25  34.002480 -117.379360     Riverside
# 7728390         2  2019-08-23 19:11:30  32.766960 -117.148060     San Diego
# 7728391         2  2019-08-23 19:00:21  33.775450 -117.847790        Orange
# 7728392         2  2019-08-23 19:00:21  33.992460 -118.403020   Culver City
# 7728393         2  2019-08-23 18:52:06  34.133930 -117.230920      Highland
#
#                  County State  Temperature(F)  Wind_Chill(F)  Humidity(%)  \
# 0            Montgomery    OH            36.9           43.0         91.0
# 1              Franklin    OH            37.9           41.0        100.0
# 2              Clermont    OH            36.0           33.3        100.0
# 3            Montgomery    OH            35.1           31.0         96.0
# 4            Montgomery    OH            36.0           33.3         89.0
# ...                 ...   ...             ...            ...          ...
# 7728389       Riverside    CA            86.0           86.0         40.0
# 7728390       San Diego    CA            70.0           70.0         73.0
# 7728391          Orange    CA            73.0           73.0         64.0
# 7728392     Los Angeles    CA            71.0           71.0         81.0
# 7728393  San Bernardino    CA            79.0           79.0         47.0
#
#          Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0               29.68            10.0           Calm              8.0
# 1               29.65            10.0           Calm              8.1
# 2               29.67            10.0             SW              3.5
# 3               29.64             9.0             SW              4.6
# 4               29.65             6.0             SW              3.5
# ...               ...             ...            ...              ...
# 7728389         28.92            10.0              W             13.0
# 7728390         29.39            10.0             SW              6.0
# 7728391         29.74            10.0            SSW             10.0
# 7728392         29.62            10.0             SW              8.0
# 7728393         28.63             7.0             SW              7.0
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 0                     0.02        Light Rain    False  False     False
# 1                     0.00        Light Rain    False  False     False
# 2                     0.00          Overcast    False  False     False
# 3                     0.00     Mostly Cloudy    False  False     False
# 4                     0.00     Mostly Cloudy    False  False     False
# ...                    ...               ...      ...    ...       ...
# 7728389               0.00              Fair    False  False     False
# 7728390               0.00              Fair    False  False     False
# 7728391               0.00     Partly Cloudy    False  False     False
# 7728392               0.00              Fair    False  False     False
# 7728393               0.00              Fair    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0           False     False    False    False       False    False  False
# 1           False     False    False    False       False    False  False
# 2           False     False    False    False       False    False  False
# 3           False     False    False    False       False    False  False
# 4           False     False    False    False       False    False  False
# ...           ...       ...      ...      ...         ...      ...    ...
# 7728389     False     False    False    False       False    False  False
# 7728390     False     False    False    False       False    False  False
# 7728391     False      True    False    False       False    False  False
# 7728392     False     False    False    False       False    False  False
# 7728393     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0                  False           False         False          Night
# 1                  False           False         False          Night
# 2                  False            True         False          Night
# 3                  False           False         False          Night
# 4                  False            True         False            Day
# ...                  ...             ...           ...            ...
# 7728389            False           False         False            Day
# 7728390            False           False         False            Day
# 7728391            False           False         False            Day
# 7728392            False           False         False            Day
# 7728393            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 0                Night             Night                 Night
# 1                Night             Night                   Day
# 2                Night               Day                   Day
# 3                  Day               Day                   Day
# 4                  Day               Day                   Day
# ...                ...               ...                   ...
# 7728389            Day               Day                   Day
# 7728390            Day               Day                   Day
# 7728391            Day               Day                   Day
# 7728392            Day               Day                   Day
# 7728393            Day               Day                   Day
#
#                                            airport_name  airport_latitude  \
# 0                       Wright-Patterson Air Force Base         39.826099
# 1             John Glenn Columbus International Airport         39.998001
# 2                               Clermont County Airport         39.078400
# 3              James M Cox Dayton International Airport         39.902401
# 4                        Dayton-Wright Brothers Airport         39.589001
# ...                                                 ...               ...
# 7728389                     Riverside Municipal Airport         33.951900
# 7728390              Montgomery-Gibbs Executive Airport         32.815700
# 7728391  John Wayne Orange County International Airport         33.675701
# 7728392                  Santa Monica Municipal Airport         34.015800
# 7728393            San Bernardino International Airport         34.095402
#
#          airport_longitude
# 0               -84.048302
# 1               -82.891899
# 2               -84.210197
# 3               -84.219398
# 4               -84.224899
# ...                    ...
# 7728389        -117.445000
# 7728390        -117.139999
# 7728391        -117.867996
# 7728392        -118.450996
# 7728393        -117.235001
#
# [7705759 rows x 36 columns]

# %%
df[df['airport_latitude'].isna() | df['airport_longitude'].isna()]
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng  \
# 42863           2  2016-06-21 10:38:47  34.267788 -118.644249
# 42868           3  2016-06-21 10:46:04  34.207294 -118.216927
# 42879           3  2016-06-21 10:50:48  34.339706 -118.506447
# 42926           2  2016-06-21 12:16:31  34.227718 -118.185913
# 42927           2  2016-06-21 12:21:46  34.143398 -118.170792
# ...           ...                  ...        ...         ...
# 7728211         2  2019-08-23 01:59:56  42.430325 -123.252602
# 7728262         2  2019-08-23 12:20:38  42.437790 -123.285592
# 7728273         2  2019-08-23 12:52:07  45.460548 -123.803174
# 7728352         4  2019-08-23 17:01:58  40.374860 -120.399344
# 7728353         4  2019-08-23 17:01:58  40.370829 -120.400948
#
#                          City       County State  Temperature(F)  \
# 42863             Simi Valley      Ventura    CA            87.0
# 42868    La Canada Flintridge  Los Angeles    CA            64.0
# 42879                 Newhall  Los Angeles    CA            87.0
# 42926    La Canada Flintridge  Los Angeles    CA            64.0
# 42927                Pasadena  Los Angeles    CA            64.0
# ...                       ...          ...   ...             ...
# 7728211           Grants Pass    Josephine    OR            58.0
# 7728262           Grants Pass    Josephine    OR            70.0
# 7728273             Tillamook    Tillamook    OR            70.0
# 7728352            Susanville       Lassen    CA            90.0
# 7728353            Susanville       Lassen    CA            90.0
#
#          Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 42863             87.0         35.0         29.11            10.0
# 42868             63.0         67.0         29.86            10.0
# 42879             87.0         35.0         29.11            10.0
# 42926             63.0         67.0         29.86            10.0
# 42927             63.0         67.0         29.86            10.0
# ...                ...          ...           ...             ...
# 7728211           58.0         84.0         26.06            10.0
# 7728262           70.0         61.0         26.07            10.0
# 7728273           70.0         60.0         29.92            10.0
# 7728352           90.0         17.0         24.91            10.0
# 7728353           90.0         17.0         24.91            10.0
#
#         Wind_Direction  Wind_Speed(mph)  Precipitation(in) Weather_Condition  \
# 42863              SSE              8.0                0.0              Fair
# 42868             None              7.0                0.0              None
# 42879              SSE              8.0                0.0              Fair
# 42926             None              7.0                0.0              None
# 42927             None              7.0                0.0              None
# ...                ...              ...                ...               ...
# 7728211            ENE              3.0                0.0              Fair
# 7728262           CALM              0.0                0.0              Fair
# 7728273            WNW              5.0                0.0              Fair
# 7728352            VAR              7.0                0.0              Fair
# 7728353            VAR              7.0                0.0              Fair
#
#          Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  Railway  \
# 42863      False  False     False     False     False    False    False
# 42868      False  False     False     False     False    False    False
# 42879      False  False     False     False     False    False    False
# 42926      False  False     False     False     False    False    False
# 42927      False  False     False     False     False    False    False
# ...          ...    ...       ...       ...       ...      ...      ...
# 7728211    False  False     False     False     False    False    False
# 7728262    False  False     False     False     False    False    False
# 7728273    False  False     False     False     False    False    False
# 7728352    False  False     False     False     False    False    False
# 7728353    False  False     False     False     False    False    False
#
#          Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 42863         False    False  False            False           False
# 42868         False    False  False            False           False
# 42879         False    False  False            False           False
# 42926         False    False  False            False           False
# 42927         False    False  False            False           False
# ...             ...      ...    ...              ...             ...
# 7728211       False    False  False            False           False
# 7728262       False    False  False            False           False
# 7728273       False    False  False            False           False
# 7728352       False    False  False            False           False
# 7728353       False    False  False            False           False
#
#          Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 42863           False            Day            Day               Day
# 42868           False            Day            Day               Day
# 42879           False            Day            Day               Day
# 42926           False            Day            Day               Day
# 42927           False            Day            Day               Day
# ...               ...            ...            ...               ...
# 7728211         False          Night          Night             Night
# 7728262         False            Day            Day               Day
# 7728273         False            Day            Day               Day
# 7728352         False            Day            Day               Day
# 7728353         False            Day            Day               Day
#
#         Astronomical_Twilight airport_name  airport_latitude  \
# 42863                     Day      Unknown               NaN
# 42868                     Day      Unknown               NaN
# 42879                     Day      Unknown               NaN
# 42926                     Day      Unknown               NaN
# 42927                     Day      Unknown               NaN
# ...                       ...          ...               ...
# 7728211                 Night      Unknown               NaN
# 7728262                   Day      Unknown               NaN
# 7728273                   Day      Unknown               NaN
# 7728352                   Day      Unknown               NaN
# 7728353                   Day      Unknown               NaN
#
#          airport_longitude
# 42863                  NaN
# 42868                  NaN
# 42879                  NaN
# 42926                  NaN
# 42927                  NaN
# ...                    ...
# 7728211                NaN
# 7728262                NaN
# 7728273                NaN
# 7728352                NaN
# 7728353                NaN
#
# [202276 rows x 36 columns]

# %%
def haversine_distance(lat1, lon1, lat2, lon2):
    """
    Calculate the great-circle distance between two points
    on the earth (specified in decimal degrees).
    """
    # Check for missing values
    if any(pd.isna([lat1, lon1, lat2, lon2])):
        return np.nan

    # Convert decimal degrees to radians
    lon1, lat1, lon2, lat2 = map(np.radians, [lon1, lat1, lon2, lat2])

    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of earth in miles. Use 6371 for kilometers
    r = 3956
    return c * r

# %%
df['distance_to_airport(mi)'] = df.apply(
    lambda row: haversine_distance(
        row['Start_Lat'], 
        row['Start_Lng'], 
        row['airport_latitude'], 
        row['airport_longitude']
    ), 
    axis=1
)

# %%
df.head()
# Out:
#    Severity           Start_Time  Start_Lat  Start_Lng          City  \
# 0         3  2016-02-08 05:46:00  39.865147 -84.058723        Dayton
# 1         2  2016-02-08 06:07:59  39.928059 -82.831184  Reynoldsburg
# 2         2  2016-02-08 06:49:27  39.063148 -84.032608  Williamsburg
# 3         3  2016-02-08 07:23:34  39.747753 -84.205582        Dayton
# 4         2  2016-02-08 07:39:07  39.627781 -84.188354        Dayton
#
#        County State  Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 0  Montgomery    OH            36.9           43.0         91.0         29.68
# 1    Franklin    OH            37.9           41.0        100.0         29.65
# 2    Clermont    OH            36.0           33.3        100.0         29.67
# 3  Montgomery    OH            35.1           31.0         96.0         29.64
# 4  Montgomery    OH            36.0           33.3         89.0         29.65
#
#    Visibility(mi) Wind_Direction  Wind_Speed(mph)  Precipitation(in)  \
# 0            10.0           Calm              8.0               0.02
# 1            10.0           Calm              8.1               0.00
# 2            10.0             SW              3.5               0.00
# 3             9.0             SW              4.6               0.00
# 4             6.0             SW              3.5               0.00
#
#   Weather_Condition  Amenity   Bump  Crossing  Give_Way  Junction  No_Exit  \
# 0        Light Rain    False  False     False     False     False    False
# 1        Light Rain    False  False     False     False     False    False
# 2          Overcast    False  False     False     False     False    False
# 3     Mostly Cloudy    False  False     False     False     False    False
# 4     Mostly Cloudy    False  False     False     False     False    False
#
#    Railway  Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0    False       False    False  False            False           False
# 1    False       False    False  False            False           False
# 2    False       False    False  False            False            True
# 3    False       False    False  False            False           False
# 4    False       False    False  False            False            True
#
#    Turning_Loop Sunrise_Sunset Civil_Twilight Nautical_Twilight  \
# 0         False          Night          Night             Night
# 1         False          Night          Night             Night
# 2         False          Night          Night               Day
# 3         False          Night            Day               Day
# 4         False            Day            Day               Day
#
#   Astronomical_Twilight                               airport_name  \
# 0                 Night            Wright-Patterson Air Force Base
# 1                   Day  John Glenn Columbus International Airport
# 2                   Day                    Clermont County Airport
# 3                   Day   James M Cox Dayton International Airport
# 4                   Day             Dayton-Wright Brothers Airport
#
#    airport_latitude  airport_longitude  distance_to_airport(mi)
# 0         39.826099         -84.048302                 2.752093
# 1         39.998001         -82.891899                 5.800391
# 2         39.078400         -84.210197                 9.577639
# 3         39.902401         -84.219398                10.702810
# 4         39.589001         -84.224899                 3.308864

# %%
df.columns
# Out:
# Index(['Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 'City', 'County',
#        'State', 'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight', 'airport_name', 'airport_latitude',
#        'airport_longitude', 'distance_to_airport(mi)'],
#       dtype='object')

# %%
df.drop(columns=['Start_Lat', 'Start_Lng', 'City', 'County','Airport_Code', 'airport_name', 'airport_latitude', 'airport_longitude', 'Wind_Chill(F)'], inplace=True, errors='ignore')

# %%
df
# Out:
#          Severity           Start_Time State  Temperature(F)  Humidity(%)  \
# 0               3  2016-02-08 05:46:00    OH            36.9         91.0
# 1               2  2016-02-08 06:07:59    OH            37.9        100.0
# 2               2  2016-02-08 06:49:27    OH            36.0        100.0
# 3               3  2016-02-08 07:23:34    OH            35.1         96.0
# 4               2  2016-02-08 07:39:07    OH            36.0         89.0
# ...           ...                  ...   ...             ...          ...
# 7728389         2  2019-08-23 18:03:25    CA            86.0         40.0
# 7728390         2  2019-08-23 19:11:30    CA            70.0         73.0
# 7728391         2  2019-08-23 19:00:21    CA            73.0         64.0
# 7728392         2  2019-08-23 19:00:21    CA            71.0         81.0
# 7728393         2  2019-08-23 18:52:06    CA            79.0         47.0
#
#          Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 0               29.68            10.0           Calm              8.0
# 1               29.65            10.0           Calm              8.1
# 2               29.67            10.0             SW              3.5
# 3               29.64             9.0             SW              4.6
# 4               29.65             6.0             SW              3.5
# ...               ...             ...            ...              ...
# 7728389         28.92            10.0              W             13.0
# 7728390         29.39            10.0             SW              6.0
# 7728391         29.74            10.0            SSW             10.0
# 7728392         29.62            10.0             SW              8.0
# 7728393         28.63             7.0             SW              7.0
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 0                     0.02        Light Rain    False  False     False
# 1                     0.00        Light Rain    False  False     False
# 2                     0.00          Overcast    False  False     False
# 3                     0.00     Mostly Cloudy    False  False     False
# 4                     0.00     Mostly Cloudy    False  False     False
# ...                    ...               ...      ...    ...       ...
# 7728389               0.00              Fair    False  False     False
# 7728390               0.00              Fair    False  False     False
# 7728391               0.00     Partly Cloudy    False  False     False
# 7728392               0.00              Fair    False  False     False
# 7728393               0.00              Fair    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 0           False     False    False    False       False    False  False
# 1           False     False    False    False       False    False  False
# 2           False     False    False    False       False    False  False
# 3           False     False    False    False       False    False  False
# 4           False     False    False    False       False    False  False
# ...           ...       ...      ...      ...         ...      ...    ...
# 7728389     False     False    False    False       False    False  False
# 7728390     False     False    False    False       False    False  False
# 7728391     False      True    False    False       False    False  False
# 7728392     False     False    False    False       False    False  False
# 7728393     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 0                  False           False         False          Night
# 1                  False           False         False          Night
# 2                  False            True         False          Night
# 3                  False           False         False          Night
# 4                  False            True         False            Day
# ...                  ...             ...           ...            ...
# 7728389            False           False         False            Day
# 7728390            False           False         False            Day
# 7728391            False           False         False            Day
# 7728392            False           False         False            Day
# 7728393            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 0                Night             Night                 Night
# 1                Night             Night                   Day
# 2                Night               Day                   Day
# 3                  Day               Day                   Day
# 4                  Day               Day                   Day
# ...                ...               ...                   ...
# 7728389            Day               Day                   Day
# 7728390            Day               Day                   Day
# 7728391            Day               Day                   Day
# 7728392            Day               Day                   Day
# 7728393            Day               Day                   Day
#
#          distance_to_airport(mi)
# 0                       2.752093
# 1                       5.800391
# 2                       9.577639
# 3                      10.702810
# 4                       3.308864
# ...                          ...
# 7728389                 5.130412
# 7728390                 3.397634
# 7728391                 6.984253
# 7728392                 3.184000
# 7728393                 2.670384
#
# [7705759 rows x 29 columns]

# %%
df[df.isna().any(axis=1)]
# Out:
#          Severity           Start_Time State  Temperature(F)  Humidity(%)  \
# 439             2  2016-03-01 17:23:06    OH            48.2         93.0
# 601             3  2016-03-11 07:28:40    OH            44.6         69.0
# 1478            3  2016-06-27 20:42:18    CA            95.0         20.0
# 1685            2  2016-06-29 14:44:14    CA            91.4         28.0
# 1957            2  2016-07-03 03:54:45    CA            57.0         77.0
# ...           ...                  ...   ...             ...          ...
# 7728262         2  2019-08-23 12:20:38    OR            70.0         61.0
# 7728273         2  2019-08-23 12:52:07    OR            70.0         60.0
# 7728332         2  2019-08-23 10:02:30    CA            76.0         56.0
# 7728352         4  2019-08-23 17:01:58    CA            90.0         17.0
# 7728353         4  2019-08-23 17:01:58    CA            90.0         17.0
#
#          Pressure(in)  Visibility(mi) Wind_Direction  Wind_Speed(mph)  \
# 439             29.51            10.0            SSW              9.2
# 601             29.36            10.0           None             10.4
# 1478            29.87            10.0             SW              6.9
# 1685            29.94            10.0            NNW             15.0
# 1957            29.95            10.0           None              6.0
# ...               ...             ...            ...              ...
# 7728262         26.07            10.0           CALM              0.0
# 7728273         29.92            10.0            WNW              5.0
# 7728332         29.72            10.0           None              7.0
# 7728352         24.91            10.0            VAR              7.0
# 7728353         24.91            10.0            VAR              7.0
#
#          Precipitation(in) Weather_Condition  Amenity   Bump  Crossing  \
# 439                    0.0              None    False  False     False
# 601                    0.0              None    False  False     False
# 1478                   0.0              None    False  False     False
# 1685                   0.0              None    False  False     False
# 1957                   0.0              None    False  False      True
# ...                    ...               ...      ...    ...       ...
# 7728262                0.0              Fair    False  False     False
# 7728273                0.0              Fair    False  False     False
# 7728332                0.0              None    False  False     False
# 7728352                0.0              Fair    False  False     False
# 7728353                0.0              Fair    False  False     False
#
#          Give_Way  Junction  No_Exit  Railway  Roundabout  Station   Stop  \
# 439         False     False    False    False       False    False  False
# 601         False     False    False    False       False    False  False
# 1478        False     False    False    False       False    False  False
# 1685        False     False    False    False       False    False  False
# 1957        False     False    False    False       False    False  False
# ...           ...       ...      ...      ...         ...      ...    ...
# 7728262     False     False    False    False       False    False  False
# 7728273     False     False    False    False       False    False  False
# 7728332     False      True    False    False       False    False  False
# 7728352     False     False    False    False       False    False  False
# 7728353     False     False    False    False       False    False  False
#
#          Traffic_Calming  Traffic_Signal  Turning_Loop Sunrise_Sunset  \
# 439                False           False         False            Day
# 601                False           False         False            Day
# 1478               False           False         False          Night
# 1685               False           False         False            Day
# 1957               False            True         False          Night
# ...                  ...             ...           ...            ...
# 7728262            False           False         False            Day
# 7728273            False           False         False            Day
# 7728332            False           False         False            Day
# 7728352            False           False         False            Day
# 7728353            False           False         False            Day
#
#         Civil_Twilight Nautical_Twilight Astronomical_Twilight  \
# 439                Day               Day                   Day
# 601                Day               Day                   Day
# 1478               Day               Day                   Day
# 1685               Day               Day                   Day
# 1957             Night             Night                 Night
# ...                ...               ...                   ...
# 7728262            Day               Day                   Day
# 7728273            Day               Day                   Day
# 7728332            Day               Day                   Day
# 7728352            Day               Day                   Day
# 7728353            Day               Day                   Day
#
#          distance_to_airport(mi)
# 439                     7.157657
# 601                    18.624366
# 1478                    6.893167
# 1685                    3.984539
# 1957                   16.795367
# ...                          ...
# 7728262                      NaN
# 7728273                      NaN
# 7728332                10.856916
# 7728352                      NaN
# 7728353                      NaN
#
# [367278 rows x 29 columns]

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Severity                   0.000000
# Start_Time                 0.000000
# State                      0.000000
# Temperature(F)             0.000000
# Humidity(%)                0.000000
# Pressure(in)               0.000000
# Visibility(mi)             0.000000
# Wind_Direction             1.979961
# Wind_Speed(mph)            0.000000
# Precipitation(in)          0.000000
# Weather_Condition          1.957289
# Amenity                    0.000000
# Bump                       0.000000
# Crossing                   0.000000
# Give_Way                   0.000000
# Junction                   0.000000
# No_Exit                    0.000000
# Railway                    0.000000
# Roundabout                 0.000000
# Station                    0.000000
# Stop                       0.000000
# Traffic_Calming            0.000000
# Traffic_Signal             0.000000
# Turning_Loop               0.000000
# Sunrise_Sunset             0.268254
# Civil_Twilight             0.268254
# Nautical_Twilight          0.268254
# Astronomical_Twilight      0.268254
# distance_to_airport(mi)    2.624998
# dtype: float64

# %%
df.to_parquet('../data/processed/us_accidents_cleaned.parquet', index=False, engine='pyarrow')

# %%
median_dist = df['distance_to_airport(mi)'].median()
df['distance_to_airport(mi)'].fillna(median_dist, inplace=True) # DONT USE THE CODE JUST YET, IT'S NOT FINALIZED
